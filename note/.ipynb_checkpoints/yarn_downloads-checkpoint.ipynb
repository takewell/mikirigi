# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import scipy as sp
import pandas as pd
from pandas.io.json import json_normalize
import json
import datetime
import statsmodels.api as sm
plt.rcParams['font.family'] = 'IPAexGothic'
# %matplotlib inline

# %%
def convert_datetime(name):
    json = pd.read_json('../data/downloads/' + name + '_download.json')
    df_json = pd.DataFrame(json['downloads'])
    df = json_normalize(df_json['downloads'])
    df['day'] = pd.to_datetime(df['day'], infer_datetime_format=True)
    df.index = df['day']
    return df

name = 'jest'
df = convert_datetime(name)
df_w = round(df.resample(rule="W").mean())
plt.title('jest')
plt.plot(df_w['downloads'])
plt.xlabel('週毎')
plt.ylabel('ダウンロード数')
plt.xticks(rotation=70)
plt.savefig("sample.png",format = 'png', dpi=5000)
plt.show()
# ts = sm.tsa.seasonal_decompose(df_w['downloads'].values, freq=52)
# plt.plot(ts.trend)

# %%
yarn  = convert_datetime('mocha')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-efede3ad36b3> in <module>
# ----> 1 yarn  = convert_datetime('mocha')
#
# <ipython-input-3-21e84df36f77> in convert_datetime(name)
#       1 def convert_datetime(name):
# ----> 2     json = pd.read_json('../data/downloads/' + name + '_download.json')
#       3     df_json = pd.DataFrame(json['downloads'])
#       4     df = json_normalize(df_json['downloads'])
#       5     df['day'] = pd.to_datetime(df['day'], infer_datetime_format=True)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     425         return json_reader
#     426
# --> 427     result = json_reader.read()
#     428     if should_close:
#     429         try:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/json/json.py in read(self)
#     535             )
#     536         else:
# --> 537             obj = self._get_object_parser(self.data)
#     538         self.close()
#     539         return obj
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/json/json.py in _get_object_parser(self, json)
#     554         obj = None
#     555         if typ == 'frame':
# --> 556             obj = FrameParser(json, **kwargs).parse()
#     557
#     558         if typ == 'series' or obj is None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/json/json.py in parse(self)
#     650
#     651         else:
# --> 652             self._parse_no_numpy()
#     653
#     654         if self.obj is None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/json/json.py in _parse_no_numpy(self)
#     869         if orient == "columns":
#     870             self.obj = DataFrame(
# --> 871                 loads(json, precise_float=self.precise_float), dtype=None)
#     872         elif orient == "split":
#     873             decoded = {str(k): v for k, v in compat.iteritems(
#
# ValueError: Expected object or value

# %%
name = 'jest'
df = convert_datetime(name)
df_w = round(df.resample(rule="W").mean())
plt.title('jest')
# df_w['downloads'].plot()
ts = sm.tsa.seasonal_decompose(df_w['downloads'].values, freq=52)

plt.ylabel('ノイズ')


plt.plot(ts.resid)

# %%
name = 'mocha'
df = convert_datetime(name)
df_w = round(df.resample(rule="W").mean())
# df_w['downloads'].plot()
ts = sm.tsa.seasonal_decompose(df_w['downloads'].values, freq=52)
plt.plot(ts.trend)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-edc019168ca6> in <module>
#       1 name = 'mocha'
# ----> 2 df = convert_datetime(name)
#       3 df_w = round(df.resample(rule="W").mean())
#       4 # df_w['downloads'].plot()
#       5 ts = sm.tsa.seasonal_decompose(df_w['downloads'].values, freq=52)
#
# <ipython-input-3-21e84df36f77> in convert_datetime(name)
#       1 def convert_datetime(name):
# ----> 2     json = pd.read_json('../data/downloads/' + name + '_download.json')
#       3     df_json = pd.DataFrame(json['downloads'])
#       4     df = json_normalize(df_json['downloads'])
#       5     df['day'] = pd.to_datetime(df['day'], infer_datetime_format=True)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     425         return json_reader
#     426
# --> 427     result = json_reader.read()
#     428     if should_close:
#     429         try:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/json/json.py in read(self)
#     535             )
#     536         else:
# --> 537             obj = self._get_object_parser(self.data)
#     538         self.close()
#     539         return obj
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/json/json.py in _get_object_parser(self, json)
#     554         obj = None
#     555         if typ == 'frame':
# --> 556             obj = FrameParser(json, **kwargs).parse()
#     557
#     558         if typ == 'series' or obj is None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/json/json.py in parse(self)
#     650
#     651         else:
# --> 652             self._parse_no_numpy()
#     653
#     654         if self.obj is None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/io/json/json.py in _parse_no_numpy(self)
#     869         if orient == "columns":
#     870             self.obj = DataFrame(
# --> 871                 loads(json, precise_float=self.precise_float), dtype=None)
#     872         elif orient == "split":
#     873             decoded = {str(k): v for k, v in compat.iteritems(
#
# ValueError: Expected object or value

# %%
# 1657
name = 'a1-raspberry'
df = convert_datetime(name)
df_w = round(df.resample(rule="W").mean())
# df_w['downloads'].plot()
ts = sm.tsa.seasonal_decompose(df_w['downloads'].values, freq=52)
plt.plot(ts.trend)

# %%
name = 'ableat-packrat'
df = convert_datetime(name)
df_w = round(df.resample(rule="W").mean())
# df_w['downloads'].plot()
ts = sm.tsa.seasonal_decompose(df_w['downloads'].values, freq=52)
plt.plot(ts.trend)

# %%
name = 'ablecloud-matrix'
df = convert_datetime(name)
df_w = round(df.resample(rule="W").mean())
# df_w['downloads'].plot()
ts = sm.tsa.seasonal_decompose(df_w['downloads'].values, freq=52)
plt.plot(ts.trend)

# %%
name = "ableton-push"
df = convert_datetime(name)
df_w = round(df.resample(rule="W").mean())
# df_w['downloads'].plot()
ts = sm.tsa.seasonal_decompose(df_w['downloads'].values, freq=52)
plt.plot(ts.trend)

# %%
name = "agile-sdk"
df = convert_datetime(name)
df_w = round(df.resample(rule="W").mean())
ts = sm.tsa.seasonal_decompose(df_w['downloads'].values, freq=52)
plt.plot(ts.trend)

# %%
# トレンド

print(ts.trend)
# Out:
# [           nan            nan            nan            nan
#             nan            nan            nan            nan
#             nan            nan            nan            nan
#             nan            nan            nan            nan
#             nan            nan            nan            nan
#             nan            nan            nan            nan
#             nan            nan 22335.46153846 23020.10576923
#  23794.83653846 24612.82692308 25441.82692308 26315.57692308
#  27141.14423077 27812.97115385 28377.49038462 28887.83653846
#  29375.55769231 29854.875      30294.98076923 30749.97115385
#  31241.61538462 31744.40384615 32224.92307692 32582.68269231
#  32897.375      33327.04807692 33801.36538462 34262.15384615
#  34753.32692308 35267.31730769 35720.06730769 36196.74038462
#  36731.88461538 37243.64423077 37792.02884615 38390.06730769
#  38996.84615385 39618.49038462 40282.625      40982.75961538
#  41659.34615385 42264.01923077 42847.49038462 43472.00961538
#  44096.25       44547.375      44998.13461538 45645.05769231
#  46294.28846154 46853.84615385 47310.34615385 47690.72115385
#  48077.07692308 48498.97115385 48996.59615385 49564.82692308
#  50097.04807692 50645.03846154 51252.59615385 51819.66346154
#  52329.93269231 52843.97115385 53347.01923077 53836.63461538
#  54371.40384615 55051.46153846 55819.61538462 56512.36538462
#  57225.61538462 57951.25       58631.07692308 59330.57692308
#  60053.35576923 60784.69230769 61531.18269231 62117.45192308
#  62518.91346154 63025.30769231 63701.40384615 64460.44230769
#  65255.18269231 65993.14423077 66706.65384615 67385.42307692
#  68117.78846154 69127.07692308 70253.55769231 71260.43269231
#  72183.19230769 73084.43269231 74003.54807692 74915.46153846
#  75788.38461538 76700.57692308 77705.29807692 78815.82692308
#  79978.19230769 81208.43269231 82386.22115385 83466.21153846
#  84623.28846154 85859.29807692 87049.29807692 88299.39423077
#  89657.875      90927.85576923 92077.85576923 93256.25961538
#  94515.76923077 95820.56730769 97299.00961538            nan
#             nan            nan            nan            nan
#             nan            nan            nan            nan
#             nan            nan            nan            nan
#             nan            nan            nan            nan
#             nan            nan            nan            nan
#             nan            nan            nan            nan
#             nan]

# %%
plt.plot(ts.seasonal)

# %%
plt.plot(ts.resid)

# %%
winupdate_df = convert_datetime('npm-windows-upgrade')
winupdate_df_w = round(winupdate_df.resample(rule="W").mean())
winupdate_df_w['downloads'].plot()
win_ts = sm.tsa.seasonal_decompose(winupdate_df_w['downloads'].values, freq=52)

# %%
plt.plot(win_ts.trend)

# %%
plt.plot(win_ts.seasonal)

# %%
plt.plot(win_ts.resid)
